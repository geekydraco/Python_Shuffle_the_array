# %%
nums = list(map(int, input().split()))
n = int(input())

result = []

for i in range(n):
    result.append(nums[i])
    result.append(nums[i + n])

print(result)
# Out:
# [1, 4, 2, 3, 3, 2, 4, 1]
